# %%
print("hello world")
# Out:
# hello world

# %%
print("hello yazilim")
# Out:
# hello yazilim

# %%
print("benim adım {}" .format("gizem"))
# Out:
# benim adım gizem

# %%
print("benim adım {},yasim {}" .format("gizem",21))
# Out:
# benim adım gizem,yasim 21

# %%
print("benim adım {1},yasim {0}" .format("gizem",21))
# Out:
# benim adım 21,yasim gizem

# %%
 sayı=10
print(sayı)
# Out:
# 10

# %%
 sayı=sayı+1
print(sayı)
# Out:
# 11

# %%
print("benim adım {ad},yasim {yas}" .format(ad="gizem",yas=21))
# Out:
# benim adım gizem,yasim 21

# %% [markdown]
# P | Y | T | H | O | N
# ----------------------
# 0 | 1 | 2 | 3 | 4 | 5
#
# 0 |-5 | -4|-3 |-2 |-1

# %%
strvar="python"
print(strvar)
# Out:
# python

# %%
strvar[-3]
# Out:
# 'h'

# %%
strvar[2:]
# Out:
# 'thon'

# %%
strvar[:3]
print(strvar)
# Out:
# python

# %%
strvar + " ogren!"
# Out:
# ' python ogren!'

# %%
strvar * 5
# Out:
# ' python python python python python'

# %%
strvar.upper()
# Out:
# 'PYTHON'

# %%
strvar.lower()
# Out:
# 'python'

# %%
print(strvar.split())
# Out:
# ['python']

# %%
strvar.split("o")
# Out:
# ['pyth', 'n']

# %%
a=True
print(type(a))
b=False
print(a)
print(b)
c="true"
print(type(c))
# Out:
# <class 'bool'>
# True
# False
# <class 'str'>

# %%
yas1=20
yas2=18

print(yas1>18)
# Out:
# True

# %%
yas1=20
yas2=18

print(yas2>18)
# Out:
# False

# %%
yas2==18
# Out:
# True

# %% [markdown]
#  liste & set
#  [a , b ,c , d ,e ,a]
#  0 | 1 | 2 | 3 | 4 |5
#  0 |-5 |-4 |-3 |-2 |-1

# %%
liste = ["a","b","c","d","e","a"]
print(liste)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'a']

# %%
liste = liste + ["f"]
liste
# Out:
# ['a', 'b', 'c', 'd', 'e', 'a', 'f']

# %%
liste[3:5]
# Out:
# ['d', 'e']

# %%
liste.pop()
liste
# Out:
# ['a', 'b', 'c', 'd', 'e', 'a']

# %%
liste.pop(5)
liste
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
sayılar= [1,1,5,2,3,9,4]
sayılar.sort()

# %%
sayılar
# Out:
# [1, 1, 2, 3, 4, 5, 9]

# %%
sayılar.reverse()
print(sayılar)
# Out:
# [9, 5, 4, 3, 2, 1, 1]

# %%
set(sayılar)
# Out:
# {1, 2, 3, 4, 5, 9}

# %%
liste = ["a","b","c","d","e","a"]
print(liste)
tup = ("a","b","c","d","e","a")
print(tup)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'a']
# ('a', 'b', 'c', 'd', 'e', 'a')

# %%
liste[0]=123412
liste
# Out:
# [123412, 'b', 'c', 'd', 'e', 'a']

# %%
tup.count("a")
# Out:
# 2

# %%
tup.count("b")
# Out:
# 1

# %%
tup.index("b")
# Out:
# 1

# %% [markdown]
# Dictionary

# %%
dict1 = {"isim": "Gizem", "yas":21,"locasyon":"berlin"}
dict1
# Out:
# {'isim': 'Gizem', 'yas': 21, 'locasyon': 'berlin'}

# %%
dict2={
    "isim":"Gizem",
    "yas":21,
    "locasyon": {
        "dogdugu_sehir":"istanbul",
        "yasadıgı_sehir":"berlin",
    }
}
dict2
# Out:
# {'isim': 'Gizem',
#  'yas': 21,
#  'locasyon': {'dogdugu_sehir': 'istanbul', 'yasadıgı_sehir': 'berlin'}}

# %%
dict2["yas"]
# Out:
# 21

# %%
dict2["locasyon"]["yasadıgı_sehir"]
# Out:
# 'berlin'

# %%
dict2.get("locasyon").get("yasadıgı_sehir")
# Out:
# 'berlin'

# %%
dict2.keys()
# Out:
# dict_keys(['isim', 'yas', 'locasyon'])

# %%
dict2.values()
# Out:
# dict_values(['Gizem', 21, {'dogdugu_sehir': 'istanbul', 'yasadıgı_sehir': 'berlin'}])

# %%
dict2.items()
# Out:
# dict_items([('isim', 'Gizem'), ('yas', 21), ('locasyon', {'dogdugu_sehir': 'istanbul', 'yasadıgı_sehir': 'berlin'})])
